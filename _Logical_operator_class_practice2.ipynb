# %% [markdown]
# ## Problem 1: Check sign
#
# **Question:** Write a program that checks if a number is positive, negative, or zero.
#
# **Approach:** Think about comparing the number with 0 using if, elif, and else.

# %%
# Enter your answer here
number  int(input("enter any number"))

if number>0:
  print("positive")
elif number<0:
  print("negative")

# %% [markdown]
# ## Problem 2: Leap Year
#
# **Question:** Check if a given year is a leap year.
#
# **Approach:** Apply the rules: divisible by 4, but centuries must be divisible by 400.
#
# Rules: Year divisible by 4 is leap, but if divisible by 100 it must also be divisible by 400.

# %%
# Enter your answer here
year = int(input("enter a year"))

if year%4==0 or (year%100==0 and  year%400 ==0):
  print("leap year")
else:
  print("not leap year")
# Out:
# enter a year2000
# leap year

# %% [markdown]
# ## Problem 3: Grade Bands
#
# **Question:** Print grade category based on marks: Excellent, Good, Average, Fail.
#
# **Approach:** Build multiple conditions using elif to check ranges.
#
# Take marks (0-100) and print:
# - 90–100 → Excellent
# - 75–89 → Good
# - 50–74 → Average
# - else → Fail

# %%
# Enter your answer here
marks = int(input("enter your marks"))
if 90<=marks<100:
  print("excellent")
elif 75<=marks<90:
  print("good")
elif 50<=marks<75:
  print("average")
else:
  print("fail")
# Out:
# enter your marks35
# fail

# %% [markdown]
# ## Problem 4: Validate Login
#
# **Question:** Check username=='admin' and password=='1234'.
#
# **Approach:** Use logical AND to validate both conditions.
#
#
# Input: username & password.
#
# If username == 'admin' and password == '1234'
# print 'Login successful',
# else 'Invalid credentials'.

# %%
# Enter your answer here
username = input("enter username")
password = input("enter password")

if username=='admin' and password=='1234':
  print("Login successful! Login ho gya bhai")
else:
  print("Invalid credentials! sahi password dal bhai")
# Out:
# enter usernamesdfs
# enter passwordsfd
# Invalid credentials! sahi password dal bhai

# %% [markdown]
# ## Problem 5: Movie Ticket Discount
#
# **Question:** Apply discount based on age.
#
# **Approach:** Use ordered elif statements from smallest to largest age group.
#
# Apply discounts based on age:
# - Age < 12 → 50% discount
# - Age between 12 and 18 → 30% discount
# - Age between 18 and 60 → no discount
# - Age > 60 → 40% discount

# %%
# Enter your answer here
age = int(input("enter your age"))
if age>60:
  print("40% discount")
elif 18<age<=60:
  print("no discount")
elif 12<=age<18:
  print("30% discount")
else:
  print("50% discount")
# Out:
# enter your age5
# 50% discount

# %% [markdown]
# ## Problem 6: Placement Eligibility
#
# **Question:** Check CGPA, backlog status, and project count.
#
# **Approach:** All conditions must be true → use AND operator.
#
#
# Conditions:
# - CGPA ≥ 7
# - No backlog (enter 'yes' or 'no')
# - Completed >= 2 major projects
# Print whether the student is eligible.

# %%
# Enter your answer here
CGPA = int(input("enter your cgpa"))
backlog = input("any backlog? yes or no")
projects = int(input("Enter number of major projects completed: "))

if CGPA>=7 and backlog == "no" and projects >= 2:
  print("elligible")
else:
  print("not elligible")
# Out:
# enter your cgpa2
# any backlog? yes or noyes
# Enter number of major projects completed: 9
# not elligible

# %% [markdown]
# ## Problem 7: Delivery Charge System
#
# **Question:** Calculate final delivery charge based on prime membership, amount, and distance.
#
# **Approach:** Start with prime-check, then inside it apply nested if blocks.
#
# Inputs:
# - order_amount (int)
# - is_prime_member (yes/no)
# - distance_km (float)
#
# Rules:
# - If prime member → Free delivery
# - Else:
#   - If amount ≥ 500:
#     - If distance ≤ 5 km → Free
#     - Else → ₹20 extra
#   - Else:
#     - If distance ≤ 5 km → ₹30
#     - Else → ₹50

# %%
# Enter your answer here
order_amount = int(input("enter order ammount"))
is_prime_member = input("do you have premium membership ? yes or no : ")
distance = int(input("distance in KM"))

if is_prime_member == "yes":
  print("Free delivery")
else:
  if order_amount >= 500:
    if distance <= 5:
      print("free")
    else:
      print("₹20 extra")
  else:
    if distance <= 5:
      print("free delivery")
    else:
      print("₹50")
# Out:
# enter order ammount3547
# do you have premium membership ? yes or no : no
# distance in KM86
# ₹20 extra

# %% [markdown]
# ## Problem 8: ATM Withdrawal Simulation
#
# **Question:** Simulate ATM rules: multiples of 100, sufficient balance, manager approval.
#
# **Approach:** Check errors first, then nested conditions for amount > 10000.
#
# Inputs:
# - balance
# - amount
#
# Logic:
# - If amount % 100 != 0 → reject (ATM works with ₹100 multiples)
# - If amount > balance → reject
# - Else:
#   - if amount > 10000 → ask for manager approval
#   - else → withdraw success

# %%
# Enter your answer here
balance = float(input("Enter your account balance: "))
amount = float(input("Enter withdrawal amount: "))

if amount % 100 != 0:
    print(" Transaction Failed: Amount must be in multiples of ₹100.")

elif amount > balance:
    print(" Transaction Failed: Insufficient balance.")
else:
    if amount > 10000:
        approval = input("Amount exceeds ₹10,000. Manager approval required (yes/no): ")
        if approval == "yes":
            print("Withdrawal Successful (Manager Approved)")
        else:
            print(" Withdrawal Failed: Manager approval denied.")
    else:
        print(" Withdrawal Successful!")
# Out:
# Enter your account balance: 6875
# Enter withdrawal amount: 700
#  Withdrawal Successful!

# %% [markdown]
# ## Problem 9: Employee Performance Rating
#
# **Question:** Assign performance rating based on sales, feedback, attendance.
#
# **Approach:** Prioritize attendance rule, then apply nested conditions.
#
# Inputs:
# - sales (₹)
# - feedback (0-5 scale)
# - attendance (%)
#
# Logic:
# - If attendance < 70 → 'Poor'
# - Else:
#   - If sales > 100000 AND feedback > 4.5 → 'Excellent'
#   - If sales > 70000 OR feedback > 4 → 'Good'
#   - Else → 'Average'

# %%
# Enter your answer here
sales = float(input("Enter total sales (₹): "))
feedback = float(input("Enter feedback rating (0–5): "))
attendance = float(input("Enter attendance percentage: "))

if attendance < 70:
    print("Performance Rating: Poor")

else:
    if sales > 100000 and feedback > 4.5:
        print("Performance Rating: Excellent")
    elif sales > 70000 or feedback > 4:
        print("Performance Rating: Good")
    else:
        print("Performance Rating: Average")
# Out:
# Enter total sales (₹): 466
# Enter feedback rating (0–5): 4
# Enter attendance percentage: 57
# Performance Rating: Poor

# %% [markdown]
# ## Problem 10: Credit Card Eligibility
#
# **Question:** Determine card eligibility based on age, salary, credit score.
#
# **Approach:** First filter by age, then use nested if blocks for salary and credit score.
#
# Inputs:
# - salary
# - credit_score
# - age
#
# Logic:
# - If age < 21 → Not eligible
# - Else:
#   - If salary ≥ 40,000:
#     - If credit_score ≥ 750 → Gold Card
#     - Else → Silver Card
#   - Else:
#     - If credit_score ≥ 800 → Silver Card
#     - Else → Not eligible

# %%
# Enter your answer here
age = int(input("Enter age: "))
salary = float(input("Enter monthly salary: "))
credit_score = int(input("Enter credit score: "))

if age < 21:
    print("Card Eligibility: Not eligible")
else:
    if salary >= 40000:
        if credit_score >= 750:
            print("Card Eligibility: Gold Card")
        else:
            print("Card Eligibility: Silver Card")
    else:
        if credit_score >= 800:
            print("Card Eligibility: Silver Card")
        else:
            print("Card Eligibility: Not eligible")
# Out:
# Enter age: 46
# Enter monthly salary: 7566
# Enter credit score: 644
# Card Eligibility: Not eligible
